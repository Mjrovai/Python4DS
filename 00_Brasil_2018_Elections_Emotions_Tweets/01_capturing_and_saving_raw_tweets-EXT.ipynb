# %% [markdown]
# # Capturing and saving Raw Tweets
# by Marcelo Rovai

# %% [markdown]
# ## Preparation

# %% [raw]
# !pip install tweepy

# %% [markdown]
# ###  General Libraries

# %%
import sys
import tweepy
import csv
import pickle
from sklearn.externals import joblib

# %% [markdown]
# ### Twitter

# %%
consumer_key = 'XXXXXX'
consumer_secret = 'XXXXXX'
access_token = 'XXXXXX'
access_token_secret = 'XXXXXX'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %% [markdown]
# ###  Creating a List of Tweets

# %%
def get_all_tweets(screen_name):
    
    alltweets = []
    new_tweets = api.user_timeline(screen_name = screen_name, count=200, tweet_mode='extended')
    alltweets.extend(new_tweets)
    oldest = alltweets[-1].id - 1

    while len(new_tweets) > 0:
        new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest, tweet_mode='extended')
        alltweets.extend(new_tweets)
        oldest = alltweets[-1].id - 1
        print ("...%s tweets downloaded so far" % (len(alltweets)))

    outtweets = [[tweet.created_at, tweet.full_text] for tweet in alltweets]
    return outtweets, alltweets

# %% [markdown]
# ---

# %% [markdown]
# ## Capturing and saving raw tweets from a Tweeter user

# %%
screen_name = 'jairbolsonaro'
tweets, alltweets = get_all_tweets(screen_name)
# Out:
# ...400 tweets downloaded so far
# ...600 tweets downloaded so far
# ...794 tweets downloaded so far
# ...994 tweets downloaded so far
# ...1193 tweets downloaded so far
# ...1393 tweets downloaded so far
# ...1589 tweets downloaded so far
# ...1787 tweets downloaded so far
# ...1983 tweets downloaded so far
# ...2180 tweets downloaded so far
# ...2379 tweets downloaded so far
# ...2579 tweets downloaded so far
# ...2776 tweets downloaded so far
# ...2973 tweets downloaded so far
# ...3169 tweets downloaded so far
# ...3185 tweets downloaded so far
# ...3185 tweets downloaded so far

# %%
# Save full raw tweets as a pickle in a file
joblib.dump(alltweets, './raw_data/'+screen_name+'_raw_tweets.pkl')
# Out:
# ['./raw_data/jairbolsonaro_raw_tweets.pkl']

# %% [markdown]
# ---

# %%
screen_name = 'CarlosBolsonaro'
tweets, alltweets = get_all_tweets(screen_name)
# Out:
# ...399 tweets downloaded so far
# ...597 tweets downloaded so far
# ...796 tweets downloaded so far
# ...993 tweets downloaded so far
# ...1192 tweets downloaded so far
# ...1392 tweets downloaded so far
# ...1590 tweets downloaded so far
# ...1790 tweets downloaded so far
# ...1988 tweets downloaded so far
# ...2184 tweets downloaded so far
# ...2382 tweets downloaded so far
# ...2576 tweets downloaded so far
# ...2767 tweets downloaded so far
# ...2958 tweets downloaded so far
# ...3145 tweets downloaded so far
# ...3150 tweets downloaded so far
# ...3150 tweets downloaded so far

# %%
# Save full raw tweets as a pickle in a file
joblib.dump(alltweets, './raw_data/'+screen_name+'_raw_tweets.pkl')
# Out:
# ['./raw_data/CarlosBolsonaro_raw_tweets.pkl']

# %% [markdown]
# ---

# %%
screen_name = 'BolsonaroSP'
tweets, alltweets = get_all_tweets(screen_name)

# Save full raw tweets as a pickle in a file
joblib.dump(alltweets, './raw_data/'+screen_name+'_raw_tweets.pkl')
# Out:
# ...400 tweets downloaded so far
# ...600 tweets downloaded so far
# ...799 tweets downloaded so far
# ...999 tweets downloaded so far
# ...1198 tweets downloaded so far
# ...1397 tweets downloaded so far
# ...1597 tweets downloaded so far
# ...1796 tweets downloaded so far
# ...1996 tweets downloaded so far
# ...2196 tweets downloaded so far
# ...2396 tweets downloaded so far
# ...2594 tweets downloaded so far
# ...2790 tweets downloaded so far
# ...2989 tweets downloaded so far
# ...3188 tweets downloaded so far
# ...3221 tweets downloaded so far
# ...3221 tweets downloaded so far
# ['./raw_data/BolsonaroSP_raw_tweets.pkl']

# %% [markdown]
# ---

# %%
screen_name = 'FlavioBolsonaro'
tweets, alltweets = get_all_tweets(screen_name)

# Save full raw tweets as a pickle in a file
joblib.dump(alltweets, './raw_data/'+screen_name+'_raw_tweets.pkl')
# Out:
# ...399 tweets downloaded so far
# ...599 tweets downloaded so far
# ...797 tweets downloaded so far
# ...991 tweets downloaded so far
# ...1187 tweets downloaded so far
# ...1386 tweets downloaded so far
# ...1582 tweets downloaded so far
# ...1775 tweets downloaded so far
# ...1971 tweets downloaded so far
# ...2164 tweets downloaded so far
# ...2356 tweets downloaded so far
# ...2549 tweets downloaded so far
# ...2744 tweets downloaded so far
# ...2936 tweets downloaded so far
# ...3135 tweets downloaded so far
# ...3182 tweets downloaded so far
# ...3182 tweets downloaded so far
# ['./raw_data/FlavioBolsonaro_raw_tweets.pkl']

# %% [markdown]
# ---

# %%
screen_name = 'LulaOficial'
tweets, alltweets = get_all_tweets(screen_name)

# Save full raw tweets as a pickle in a file
joblib.dump(alltweets, './raw_data/'+screen_name+'_raw_tweets.pkl')
# Out:
# ...400 tweets downloaded so far
# ...600 tweets downloaded so far
# ...800 tweets downloaded so far
# ...1000 tweets downloaded so far
# ...1200 tweets downloaded so far
# ...1400 tweets downloaded so far
# ...1600 tweets downloaded so far
# ...1800 tweets downloaded so far
# ...2000 tweets downloaded so far
# ...2200 tweets downloaded so far
# ...2400 tweets downloaded so far
# ...2600 tweets downloaded so far
# ...2800 tweets downloaded so far
# ...3000 tweets downloaded so far
# ...3200 tweets downloaded so far
# ...3237 tweets downloaded so far
# ...3237 tweets downloaded so far
# ['./raw_data/LulaOficial_raw_tweets.pkl']

# %% [markdown]
# ---

# %%
screen_name = 'gleisi'
tweets, alltweets = get_all_tweets(screen_name)

# Save full raw tweets as a pickle in a file
joblib.dump(alltweets, './raw_data/'+screen_name+'_raw_tweets.pkl')
# Out:
# ...400 tweets downloaded so far
# ...600 tweets downloaded so far
# ...800 tweets downloaded so far
# ...1000 tweets downloaded so far
# ...1200 tweets downloaded so far
# ...1400 tweets downloaded so far
# ...1600 tweets downloaded so far
# ...1800 tweets downloaded so far
# ...2000 tweets downloaded so far
# ...2200 tweets downloaded so far
# ...2400 tweets downloaded so far
# ...2599 tweets downloaded so far
# ...2799 tweets downloaded so far
# ...2999 tweets downloaded so far
# ...3199 tweets downloaded so far
# ...3241 tweets downloaded so far
# ...3241 tweets downloaded so far
# ['./raw_data/gleisi_raw_tweets.pkl']

# %% [markdown]
# ---

# %%
screen_name = 'BlogDoPim'
tweets, alltweets = get_all_tweets(screen_name)

# Save full raw tweets as a pickle in a file
joblib.dump(alltweets, './raw_data/'+screen_name+'_raw_tweets.pkl')
# Out:
# ...400 tweets downloaded so far
# ...600 tweets downloaded so far
# ...800 tweets downloaded so far
# ...999 tweets downloaded so far
# ...1199 tweets downloaded so far
# ...1399 tweets downloaded so far
# ...1599 tweets downloaded so far
# ...1799 tweets downloaded so far
# ...1999 tweets downloaded so far
# ...2199 tweets downloaded so far
# ...2399 tweets downloaded so far
# ...2599 tweets downloaded so far
# ...2799 tweets downloaded so far
# ...2999 tweets downloaded so far
# ...3199 tweets downloaded so far
# ...3219 tweets downloaded so far
# ...3219 tweets downloaded so far
# ['./raw_data/BlogDoPim_raw_tweets.pkl']

# %% [markdown]
# ---

# %%
screen_name = 'Haddad_Fernando'
tweets, alltweets = get_all_tweets(screen_name)

# Save full raw tweets as a pickle in a file
joblib.dump(alltweets, './raw_data/'+screen_name+'_raw_tweets.pkl')
# Out:
# ...399 tweets downloaded so far
# ...599 tweets downloaded so far
# ...799 tweets downloaded so far
# ...999 tweets downloaded so far
# ...1199 tweets downloaded so far
# ...1399 tweets downloaded so far
# ...1599 tweets downloaded so far
# ...1799 tweets downloaded so far
# ...1999 tweets downloaded so far
# ...2199 tweets downloaded so far
# ...2399 tweets downloaded so far
# ...2599 tweets downloaded so far
# ...2799 tweets downloaded so far
# ...2999 tweets downloaded so far
# ...3199 tweets downloaded so far
# ...3215 tweets downloaded so far
# ...3215 tweets downloaded so far
# ['./raw_data/Haddad_Fernando_raw_tweets.pkl']

# %% [markdown]
# ---
# ## Tests

# %%
import matplotlib.pyplot as plt
import networkx as nx

# %%
screen_name = 'mjrovai'
tweets, alltweets = get_all_tweets(screen_name)
# Out:
# ...176 tweets downloaded so far

# %%
print ("Loading users who follow",screen_name,"...")
followers = []
for page in tweepy.Cursor(api.followers_ids, screen_name).pages():
    followers.extend(page)
    time.sleep(1)
print ("Loaded ",len(followers), "followers")
# Out:
# Loading users who follow mjrovai ...
# Loaded  32 followers

# %%
print ("Loading users that", screen_name, "follows...")
friends = []
for page in tweepy.Cursor(api.friends_ids, screen_name).pages():
    friends.extend(page)
    time.sleep(1)
print ("Loaded ",len(friends), "friends")
# Out:
# Loading users that mjrovai follows...
# Loaded  78 friends

# %%
G=nx.DiGraph()
for user in followers:
    G.add_edge(user, screen_name)
for user in friends:
    G.add_edge(screen_name,user)

# %%
plt.figure(figsize=(10,10))
plt.axis("off")
nx.draw(G, with_labels=False, node_size=30)
